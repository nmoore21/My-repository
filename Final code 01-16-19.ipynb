# %%
pwd
# Out:
# '/Users/ninamoore'

# %%
cd Downloads
# Out:
# /Users/ninamoore/Downloads

# %%
import json
from urllib.parse import urlparse, parse_qs
with open('logstash-mv-2017.04-dump.txt','r') as f:
    count = 0
    count1 = 0
    count2 = 0
    count3 = 0
    count_dict = {
        "notspecified": 0,   # when fields parameter is not specified
        "clinvar": 0,
        "cadd": 0,
        "cosmic": 0,
        "cgi": 0,
        "civic": 0,
        "dbsnp":0,
        "dbnsfp":0,
        "docm": 0,
        "emv": 0,
        "evs": 0,
        "exac": 0,
        "exac_nontcga": 0,
        "geno2mp": 0,
        "gnomad_exomes": 0,
        "gnomad_genomes": 0,
        "grasp": 0,
        "gwassnps": 0,
        "mutdb": 0,
        "snpedia": 0,
        "snpeff": 0,
        "all": 0,
        "wellderly": 0,
    }
    for line in f:
        data = json.loads(line)
        if "@fields" in data and data["@fields"]["request_method"]== "GET":
            count1 += 1
        if "@fields" in data and 'GET /v1/variant/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            count2 += 1 
            url = data["@fields"]["request"]
            url1 = url.split(' ')
            url2 = url1[1]
            o = urlparse(url2)
            d = parse_qs(o.query)
            if 'fields' in d:
                fields_list = ','.join(d["fields"]).split(',')
                count += 1
                source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                for source in source_list:
                    if source in count_dict:
                        count_dict[source] += 1
        if "@fields" in data and 'GET /v1/query/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            count3 += 1 
            url = data["@fields"]["request"]
            url1 = url.split(' ')
            url2 = url1[1]
            o = urlparse(url2)
            d = parse_qs(o.query)
            if 'fields' in d:
                fields_list = ','.join(d["fields"]).split(',')
                count += 1
                source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                for source in source_list:
                    if source in count_dict:
                        count_dict[source] += 1

    print("logstash-mv-2017.04-dump.txt"); print("GET", count1); print("GET, v1/variant", count2); print("GET, v1/query", count3); print(count_dict)
    
with open('logstash-mv-2017.05-dump.txt','r') as f:
    count = 0
    count1 = 0
    count2 = 0   #count_variant_get
    count3 = 0   #count_query_get
    count_dict = {
        "clinvar": 0,
        "cadd": 0,
        "cosmic": 0,
        "dbsnp":0,
        "dbnsfp":0,
        "emv": 0,
        "exac": 0,
        "snpeff": 0,
        "all": 0
    }
    for line in f:
        data = json.loads(line)
        if "@fields" in data and data["@fields"]["request_method"]== "GET":
            count1 += 1
        if "@fields" in data and 'GET /v1/variant/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            count2 += 1 
            url = data["@fields"]["request"]
            url1 = url.split(' ')
            url2 = url1[1]
            o = urlparse(url2)
            d = parse_qs(o.query)
            if 'fields' in d:
                fields_list = ','.join(d["fields"]).split(',')
                count += 1
                source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                for source in source_list:
                    if source in count_dict:
                        count_dict[source] += 1
        if "@fields" in data and 'GET /v1/query/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            count3 += 1 
            url = data["@fields"]["request"]
            url1 = url.split(' ')
            url2 = url1[1]
            o = urlparse(url2)
            d = parse_qs(o.query)
            if 'fields' in d:
                fields_list = ','.join(d["fields"]).split(',')
                count += 1
                source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                for source in source_list:
                    if source in count_dict:
                        count_dict[source] += 1

    print("logstash-mv-2017.05-dump.txt"); print("GET", count1); print("GET, v1/variant", count2); print("GET, v1/query", count3); print(count_dict)

with open('logstash-mv-2017.06-dump.txt','r') as f:
    count = 0
    count1 = 0
    count2 = 0
    count3 = 0
    count_dict = {
        "clinvar": 0,
        "cadd": 0,
        "cosmic": 0,
        "dbsnp":0,
        "dbnsfp":0,
        "emv": 0,
        "exac": 0,
        "snpeff": 0,
        "all": 0
    }
    for line in f:
        data = json.loads(line)
        if "@fields" in data and data["@fields"]["request_method"]== "GET":
            count1 += 1
        if "@fields" in data and 'GET /v1/variant/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            count2 += 1 
            url = data["@fields"]["request"]
            url1 = url.split(' ')
            url2 = url1[1]
            o = urlparse(url2)
            d = parse_qs(o.query)
            if 'fields' in d:
                fields_list = ','.join(d["fields"]).split(',')
                count += 1
                source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                for source in source_list:
                    if source in count_dict:
                        count_dict[source] += 1
        if "@fields" in data and 'GET /v1/query/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            count3 += 1 
            url = data["@fields"]["request"]
            url1 = url.split(' ')
            url2 = url1[1]
            o = urlparse(url2)
            d = parse_qs(o.query)
            if 'fields' in d:
                fields_list = ','.join(d["fields"]).split(',')
                count += 1
                source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                for source in source_list:
                    if source in count_dict:
                        count_dict[source] += 1

    print("logstash-mv-2017.06-dump.txt"); print("GET", count1); print("GET, v1/variant", count2); print("GET, v1/query", count3); print(count_dict)
# Out:
# logstash-mv-2017.04-dump.txt
# GET 1309634
# GET, v1/variant 827556
# GET, v1/query 5506
# {'notspecified': 0, 'clinvar': 8728, 'cadd': 5149, 'cosmic': 8971, 'cgi': 0, 'civic': 0, 'dbsnp': 4237, 'dbnsfp': 5880, 'docm': 0, 'emv': 3197, 'evs': 0, 'exac': 4298, 'exac_nontcga': 4090, 'geno2mp': 0, 'gnomad_exomes': 0, 'gnomad_genomes': 0, 'grasp': 0, 'gwassnps': 0, 'mutdb': 0, 'snpedia': 0, 'snpeff': 3808, 'all': 64, 'wellderly': 0}
# logstash-mv-2017.05-dump.txt
# GET 1770730
# GET, v1/variant 536252
# GET, v1/query 28804
# {'clinvar': 19853, 'cadd': 14636, 'cosmic': 5216, 'dbsnp': 5354, 'dbnsfp': 5017, 'emv': 4589, 'exac': 8746, 'snpeff': 160221, 'all': 74}
# logstash-mv-2017.06-dump.txt
# GET 497177
# GET, v1/variant 53983
# GET, v1/query 92756
# {'clinvar': 6838, 'cadd': 6609, 'cosmic': 12726, 'dbsnp': 7245, 'dbnsfp': 6761, 'emv': 6258, 'exac': 9729, 'snpeff': 6310, 'all': 125}

# %%
import json
from urllib.parse import urlparse, parse_qs

def parse_myvariant_logfile(mv_logfile):
    count_get = 0
    count_variant = 0
    count_query = 0
    count_dict = {
        "no_fields": 0,   # when fields parameter is not specified
        "with_fields": 0, # when fields parameter is specified
        "clinvar": 0,
        "cadd": 0,
        "cosmic": 0,
        "cgi": 0,
        "civic": 0,
        "dbsnp":0,
        "dbnsfp":0,
        "docm": 0,
        "emv": 0,
        "evs": 0,
        "exac": 0,
        "exac_nontcga": 0,
        "geno2mp": 0,
        "gnomad_exomes": 0,
        "gnomad_genomes": 0,
        "grasp": 0,
        "gwassnps": 0,
        "mutdb": 0,
        "snpedia": 0,
        "snpeff": 0,
        "all": 0,
        "wellderly": 0,
    }
    print("Processing {}...".format(mv_logfile))
    with open(mv_logfile) as f:
        for line in f:
            data = json.loads(line)
            #if "@fields" in data and 'GET /v1/variant/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET" or "@fields" in data and 'GET /v1/query/' in data["@fields"]["request"] and data["@fields"]["request_method"]== "GET":
            if "@fields" in data and data["@fields"]["request_method"]== "GET":
                count_get += 1
                if 'GET /v1/variant/' in data["@fields"]["request"] or \
                   'GET /v1/query/' in data["@fields"]["request"]:
                    url = data["@fields"]["request"]
                    url1 = url.split(' ')
                    url2 = url1[1]
                    o = urlparse(url2)
                    d = parse_qs(o.query)
                    if 'fields' in d:
                        count_dict['with_fields'] += 1
                        fields_list = ','.join(d["fields"]).split(',')
                        source_list = set([fields.split('.')[0].lower() for fields in fields_list])
                        #if 'fields' in d and 'fields' == {}:
                        #    count1 += 1
                        for source in source_list:
                            if source in count_dict:
                                count_dict[source] += 1
                    else:
                        count_dict['no_fields'] += 1
            #if "@fields" in data and data["@fields"]["request_method"]== "GET":
            #    count_get += 1
                if 'GET /v1/variant/' in data["@fields"]["request"]:
                    count_variant += 1
                if 'GET /v1/query/' in data["@fields"]["request"]:
                    count_query += 1 
   
    
    print("GET", count_get)
    print("GET, v1/variant", count_variant)
    print("GET, v1/query", count_query)
    print(count_dict)
    


parse_myvariant_logfile('logstash-mv-2017.04-dump.txt')


parse_myvariant_logfile('logstash-mv-2017.05-dump.txt')


parse_myvariant_logfile('logstash-mv-2017.06-dump.txt')
# Out:
# Processing logstash-mv-2017.04-dump.txt...
# GET 1309634
# GET, v1/variant 827556
# GET, v1/query 5506
# {'no_fields': 812322, 'with_fields': 20740, 'clinvar': 8728, 'cadd': 5149, 'cosmic': 8971, 'cgi': 0, 'civic': 0, 'dbsnp': 4237, 'dbnsfp': 5880, 'docm': 0, 'emv': 3197, 'evs': 0, 'exac': 4298, 'exac_nontcga': 4090, 'geno2mp': 0, 'gnomad_exomes': 0, 'gnomad_genomes': 0, 'grasp': 0, 'gwassnps': 0, 'mutdb': 0, 'snpedia': 0, 'snpeff': 3808, 'all': 64, 'wellderly': 0}
# Processing logstash-mv-2017.05-dump.txt...
# GET 1770730
# GET, v1/variant 536252
# GET, v1/query 28804
# {'no_fields': 374998, 'with_fields': 190058, 'clinvar': 19853, 'cadd': 14636, 'cosmic': 5216, 'cgi': 0, 'civic': 0, 'dbsnp': 5354, 'dbnsfp': 5017, 'docm': 0, 'emv': 4589, 'evs': 1, 'exac': 8746, 'exac_nontcga': 4602, 'geno2mp': 0, 'gnomad_exomes': 0, 'gnomad_genomes': 0, 'grasp': 1, 'gwassnps': 0, 'mutdb': 0, 'snpedia': 0, 'snpeff': 160221, 'all': 74, 'wellderly': 1}
# Processing logstash-mv-2017.06-dump.txt...
# GET 497177
# GET, v1/variant 53983
# GET, v1/query 92756
# {'no_fields': 43289, 'with_fields': 103450, 'clinvar': 6838, 'cadd': 6609, 'cosmic': 12726, 'cgi': 0, 'civic': 0, 'dbsnp': 7245, 'dbnsfp': 6761, 'docm': 0, 'emv': 6258, 'evs': 25, 'exac': 9729, 'exac_nontcga': 6277, 'geno2mp': 0, 'gnomad_exomes': 0, 'gnomad_genomes': 0, 'grasp': 25, 'gwassnps': 0, 'mutdb': 1, 'snpedia': 0, 'snpeff': 6310, 'all': 125, 'wellderly': 29}

# %%
def parse_myvariant_logfile(mv_logfile)
with open(mv_logfile):
parse_myvariant_logfile('logstash-mv-2017.04-dump.txt')
print(mv_logfile)
# Out:
#   File "<ipython-input-10-ecbbfb368f18>", line 1
#     def parse_myvariant_logfile(mv_logfile)
#                                            ^
# SyntaxError: invalid syntax
